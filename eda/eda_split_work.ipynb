# %% [markdown]
# ### Polymarket

# %%
# %run eda_starter_template.py
# Out:
# [Memory] Initial memory usage: 39.97 MB
#
# Loading Bitcoin data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv...
# [Memory] Before loading Bitcoin data: 40.11 MB
# [Memory] After loading Bitcoin data: 47.95 MB (Δ 7.84 MB)
# Error loading Bitcoin data: No such file or directory (os error 2): ...ne Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv (set POLARS_VERBOSE=1 to see full path)
#
# This error occurred with the following context stack:
# 	[1] 'csv scan'
# 	[2] 'with_columns'
# 	[3] 'sink'
#
# Loading Polymarket data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket...
# [Memory] Before loading Polymarket data: 48.02 MB
# Loaded 78321 markets.
# Loaded 2143181 odds history records.
# Loaded 78321 summary records.
# [Memory] After loading Polymarket data: 250.36 MB (Δ 202.34 MB)
# [Memory] Before analyzing Polymarket summary: 250.36 MB
#
# --- Polymarket Data Summary ---
# Total Markets: 78321
# Active Markets: 78321
# Closed Markets: 0
# Total Volume: $18,203,500,864.53
# Average Volume per Market: $232,421.71
# Total Odds History Records: 2,143,181
# Total Trades: 27,013,724
# [Memory] After analyzing Polymarket summary: 250.44 MB (Δ 0.08 MB)
# [Memory] Before plotting Polymarket volume: 250.44 MB
# Saved polymarket_volume_by_category.png
# [Memory] After plotting Polymarket volume: 340.50 MB (Δ 90.06 MB)
#
# [Memory] Final memory usage: 340.50 MB (Total Δ: 300.53 MB)
#
# EDA Layout Complete. Check the 'plots' directory for visualizations.

# %%
# edit your directory
# %run '/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/download_data.py'
# Out:
# --- Downloading Capstone Data ---
# Downloading from GDrive...
# Retrieving folder contents
# Retrieving folder 1mgd1yrowPdQ0JKtdnKBQYHpvcdyRlXcV Coin Metrics
# Processing file 1IUADRKckAZVoFYIJjTt9f_la-CQmnXIN coinmetrics_btc.csv
# Processing file 1KVBZIl45-DnY0EzbA6-qFZi7kvu1iH8H coinmetrics_spec.md
# Retrieving folder 1f_RjuR2AVTpuJeX6jgeoKcspjUp9_lif Polymarket
# Processing file 14v0AUTMO6GwQ4ItLNRI8EuxLXplvCoGt finance_politics_event_stats.parquet
# Processing file 1oF4B2zvi21br9a6NFVTwjAB8mfNuLdYx finance_politics_markets.parquet
# Processing file 1z4nfPZL04Rkhp82piCvqRFerKBQbrXCh finance_politics_odds_history.parquet
# Processing file 1QrWoxsFnfxv7Qs1lR4j2wpTs20MqOLnk finance_politics_summary.parquet
# Processing file 1K1DjGkN4fkDMRXqZekS_-vRn-WErRLsz finance_politics_tokens.parquet
# Processing file 1GO00RPaS7Q2ncX0fcUHiBLyy4bZR4_Yt finance_politics_trades.parquet
# Processing file 1SwimJ6dcwl8TWUR1qKWsC1pzXAb9RHTs polymarket_btc_analytics_schema.md
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1IUADRKckAZVoFYIJjTt9f_la-CQmnXIN
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Coin Metrics/coinmetrics_btc.csv
# 100%|██████████| 2.42M/2.42M [00:00<00:00, 16.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KVBZIl45-DnY0EzbA6-qFZi7kvu1iH8H
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Coin Metrics/coinmetrics_spec.md
# 100%|██████████| 4.85k/4.85k [00:00<00:00, 7.16MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14v0AUTMO6GwQ4ItLNRI8EuxLXplvCoGt
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/finance_politics_event_stats.parquet
# 100%|██████████| 1.43M/1.43M [00:00<00:00, 6.90MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oF4B2zvi21br9a6NFVTwjAB8mfNuLdYx
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/finance_politics_markets.parquet
# 100%|██████████| 3.38M/3.38M [00:00<00:00, 14.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1z4nfPZL04Rkhp82piCvqRFerKBQbrXCh
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/finance_politics_odds_history.parquet
# 100%|██████████| 17.8M/17.8M [00:01<00:00, 14.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1QrWoxsFnfxv7Qs1lR4j2wpTs20MqOLnk
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/finance_politics_summary.parquet
# 100%|██████████| 4.52M/4.52M [00:00<00:00, 11.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1K1DjGkN4fkDMRXqZekS_-vRn-WErRLsz
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/finance_politics_tokens.parquet
# 100%|██████████| 10.4M/10.4M [00:00<00:00, 14.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1GO00RPaS7Q2ncX0fcUHiBLyy4bZR4_Yt
# From (redirected): https://drive.google.com/uc?id=1GO00RPaS7Q2ncX0fcUHiBLyy4bZR4_Yt&confirm=t&uuid=2f8455db-7945-4ae1-88d7-153b54034204
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/finance_politics_trades.parquet
# 100%|██████████| 3.31G/3.31G [09:36<00:00, 5.74MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1SwimJ6dcwl8TWUR1qKWsC1pzXAb9RHTs
# To: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/tmp_capstone_data/Polymarket/polymarket_btc_analytics_schema.md
# 100%|██████████| 4.41k/4.41k [00:00<00:00, 2.30MB/s]
# Organizing files...
#   Keeping: Coin Metrics/coinmetrics_btc.csv
#   Keeping: Coin Metrics/coinmetrics_spec.md
#   Keeping: Polymarket/finance_politics_odds_history.parquet
#   Keeping: Polymarket/finance_politics_summary.parquet
#   Keeping: Polymarket/finance_politics_trades.parquet
#   Keeping: Polymarket/finance_politics_markets.parquet
#   Keeping: Polymarket/polymarket_btc_analytics_schema.md
#   Keeping: Polymarket/finance_politics_tokens.parquet
#   Keeping: Polymarket/finance_politics_event_stats.parquet
#
# Successfully organized 9 file(s).
# --- Finished downloading ---
#
# Data download and organization complete.
# Download completed
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import os
import pandas as pd

COINMETRICS_PATH = '/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/data/Coin Metrics/coinmetrics_btc.csv'
POLYMARKET_DIR = '/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/data/Polymarket'

# Load Bitcoin data
btc_df = load_bitcoin_data(COINMETRICS_PATH)

# Debug: Check directory and files
print("\n" + "="*80)
print("POLYMARKET DATA LOADING")
print("="*80)
print(f"\nDirectory: {POLYMARKET_DIR}")
print(f"Directory exists: {os.path.exists(POLYMARKET_DIR)}")

if os.path.exists(POLYMARKET_DIR):
    print("\nFiles in directory:")
    all_files = os.listdir(POLYMARKET_DIR)
    for file in sorted(all_files):
        filepath = os.path.join(POLYMARKET_DIR, file)
        size = os.path.getsize(filepath) / (1024*1024)  # Size in MB
        print(f"  {file:50s} ({size:.2f} MB)")
else:
    print("\n✗ ERROR: Directory does not exist!")

print("\n" + "-"*80)

# Load Polymarket data with DETAILED error messages
poly_data = {}

files_to_load = [
    ('markets', 'finance_politics_markets.parquet'),
    ('odds_history', 'finance_politics_odds_history.parquet'),
    ('summary', 'finance_politics_summary.parquet'),
    ('tokens', 'finance_politics_tokens.parquet'), 
    ('trades', 'finance_politics_trades.parquet'),
    ('event_stats', 'finance_politics_event_stats.parquet')
]

for name, filename in files_to_load:
    filepath = os.path.join(POLYMARKET_DIR, filename)
    
    print(f"\n{name}:")
    print(f"  Looking for: {filename}")
    print(f"  Full path: {filepath}")
    print(f"  File exists: {os.path.exists(filepath)}")
    
    if not os.path.exists(filepath):
        print(f"  ✗ SKIPPED: File not found")
        continue
    
    try:
        poly_data[name] = pd.read_parquet(filepath)
        print(f"  ✓ SUCCESS: Loaded {len(poly_data[name]):,} rows, {len(poly_data[name].columns)} columns")
        print(f"  Columns: {', '.join(poly_data[name].columns[:5].tolist())}{'...' if len(poly_data[name].columns) > 5 else ''}")
        
    except Exception as e:
        print(f"  ✗ ERROR: {type(e).__name__}")
        print(f"  Message: {str(e)}")

# Final summary
print("\n" + "="*80)
print("SUMMARY")
print("="*80)
print(f"Bitcoin data: ✓ {len(btc_df):,} rows")
print(f"Polymarket datasets loaded: {len(poly_data)}/{len(files_to_load)}")

if len(poly_data) > 0:
    for name, df in poly_data.items():
        print(f"  ✓ {name:15s}: {len(df):,} rows")
else:
    print("\n⚠ WARNING: No Polymarket files loaded!")
    print("\nPossible reasons:")
    print("  1. Files have different names than expected")
    print("  2. Files are in a different directory")
    print("  3. Files haven't been downloaded yet")
    print("  4. pyarrow library not installed (run: pip install pyarrow)")

print("="*80)
# Out:
# Loading Bitcoin data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/eda/data/Coin Metrics/coinmetrics_btc.csv...
# [Memory] Before loading Bitcoin data: 83.33 MB
# [Memory] After loading Bitcoin data: 101.42 MB (Δ 18.09 MB)
# Successfully loaded 6221 rows.
#
# ================================================================================
# POLYMARKET DATA LOADING
# ================================================================================
#
# Directory: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket
# Directory exists: True
#
# Files in directory:
#   finance_politics_event_stats.parquet               (1.37 MB)
#   finance_politics_markets.parquet                   (3.22 MB)
#   finance_politics_odds_history.parquet              (16.96 MB)
#   finance_politics_summary.parquet                   (4.31 MB)
#   finance_politics_tokens.parquet                    (9.87 MB)
#   finance_politics_trades.parquet                    (3156.20 MB)
#   polymarket_btc_analytics_schema.md                 (0.00 MB)
#
# --------------------------------------------------------------------------------
#
# markets:
#   Looking for: finance_politics_markets.parquet
#   Full path: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket/finance_politics_markets.parquet
#   File exists: True
#   ✓ SUCCESS: Loaded 78,321 rows, 10 columns
#   Columns: market_id, question, slug, event_slug, category...
#
# odds_history:
#   Looking for: finance_politics_odds_history.parquet
#   Full path: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket/finance_politics_odds_history.parquet
#   File exists: True
#   ✓ SUCCESS: Loaded 2,143,181 rows, 4 columns
#   Columns: market_id, token_id, timestamp, price
#
# summary:
#   Looking for: finance_politics_summary.parquet
#   Full path: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket/finance_politics_summary.parquet
#   File exists: True
#   ✓ SUCCESS: Loaded 78,321 rows, 9 columns
#   Columns: market_id, question, slug, volume, active...
#
# tokens:
#   Looking for: finance_politics_tokens.parquet
#   Full path: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket/finance_politics_tokens.parquet
#   File exists: True
#   ✓ SUCCESS: Loaded 156,636 rows, 3 columns
#   Columns: market_id, token_id, outcome
#
# trades:
#   Looking for: finance_politics_trades.parquet
#   Full path: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket/finance_politics_trades.parquet
#   File exists: True

# %%
poly_data
# Out:
# {'markets':       market_id                                           question  \
#  0        242851  Will Bongbong Marcos be elected President of t...
#  1        242873  Will Sarah Palin win Alaska's special election...
#  2        242918  Will US student loan payments resume by Electi...
#  3        243183       Will $ETH be above $3,000 on April 20, 2022?
#  4        243192  Will Brian Kemp win the Republican nomination ...
#  ...         ...                                                ...
#  78316    242646  Will the total value locked (TVL) in DeFi be $...
#  78317    242686  2022 Hungarian elections: Will Fidesz win at l...
#  78318    242687  Will the price of wheat close above $1050 on A...
#  78319    242688  Will the Progressive Conservative Party win a ...
#  78320    242690  Will Joe Biden's FiveThirtyEight approval rati...
#
#                                                      slug  \
#  0      will-bongbong-marcos-be-elected-president-of-t...
#  1      will-sarah-palin-win-in-the-alaskan-special-el...
#  2      will-us-student-loan-payments-resume-by-electi...
#  3                will-eth-be-above-3000-on-april-20-2022
#  4      will-brian-kemp-win-the-republican-nomination-...
#  ...                                                  ...
#  78316  will-the-total-value-locked-in-defi-be-85-bill...
#  78317  2022-hungarian-elections-will-fidesz-retain-at...
#  78318  will-the-price-of-wheat-close-above-1050-on-ap...
#  78319  will-the-progressive-conservative-party-win-a-...
#  78320  will-joe-bidens-fivethirtyeight-approval-ratin...
#
#                                                event_slug            category  \
#  0      will-bongbong-marcos-be-elected-president-of-t...     Global Politics
#  1      will-sarah-palin-win-in-the-alaskan-special-el...  US-current-affairs
#  2      will-us-student-loan-payments-resume-by-electi...  US-current-affairs
#  3                will-eth-be-above-3000-on-april-20-2022              Crypto
#  4      who-will-win-the-republican-nomination-for-the...  US-current-affairs
#  ...                                                  ...                 ...
#  78316  will-the-total-value-locked-in-defi-be-85-bill...              Crypto
#  78317  2022-hungarian-elections-will-fidesz-retain-at...     Global Politics
#  78318  will-the-price-of-wheat-close-above-1050-on-ap...    Ukraine & Russia
#  78319  will-the-progressive-conservative-party-win-a-...     Global Politics
#  78320  will-joe-bidens-fivethirtyeight-approval-ratin...  US-current-affairs
#
#            volume  active  closed          created_at   end_date
#  0       21533.53    True    True 2022-04-05 20:37:30 2022-05-09
#  1       79783.23    True    True 2022-04-05 22:41:57 2022-08-16
#  2       18946.72    True    True 2022-04-05 23:33:47 2022-11-08
#  3      974114.26    True    True 2022-04-12 16:51:10 2022-04-20
#  4        7024.92    True    True 2022-04-13 01:40:25 2022-05-24
#  ...          ...     ...     ...                 ...        ...
#  78316    4456.20    True    True 2022-03-30 22:51:47 2022-04-17
#  78317   16801.37    True    True 2022-03-31 21:11:06 2022-04-03
#  78318   15474.27    True    True 2022-03-31 21:13:02 2022-04-29
#  78319    9075.77    True    True 2022-03-31 21:15:48 2022-06-02
#  78320   42114.06    True    True 2022-03-31 22:09:35 2022-05-01
#
#  [78321 rows x 10 columns],
#  'odds_history':         market_id                                           token_id  \
#  0          255140  4743579536152330606866939019100172195245171947...
#  1          255140  4743579536152330606866939019100172195245171947...
#  2          255140  4743579536152330606866939019100172195245171947...
#  3          255140  4743579536152330606866939019100172195245171947...
#  4          255140  4743579536152330606866939019100172195245171947...
#  ...           ...                                                ...
#  2143176    897329  1441341842174471672181235644969822857103541674...
#  2143177    897329  1441341842174471672181235644969822857103541674...
#  2143178    897329  1441341842174471672181235644969822857103541674...
#  2143179    897329  1441341842174471672181235644969822857103541674...
#  2143180    897329  1441341842174471672181235644969822857103541674...
#
#                        timestamp   price
#  0       1970-01-20 21:10:04.802  0.0550
#  1       1970-01-20 21:11:31.203  0.0550
#  2       1970-01-20 21:12:57.604  0.0550
#  3       1970-01-20 21:14:24.002  0.0550
#  4       1970-01-20 21:15:50.403  0.0550
#  ...                         ...     ...
#  2143176 1970-01-21 10:55:12.022  0.9595
#  2143177 1970-01-21 10:56:38.419  0.9595
#  2143178 1970-01-21 10:58:04.822  0.9640
#  2143179 1970-01-21 10:59:31.225  0.9640
#  2143180 1970-01-21 10:59:32.413  0.9640
#
#  [2143181 rows x 4 columns],
#  'summary':       market_id                                           question  \
#  0        798778  Will the price of Bitcoin be between $88,000 a...
#  1        893560  Ethereum Up or Down - December 9, 12:30AM-12:4...
#  2        821729  Will the price of Solana be above $180 on Dece...
#  3        687200  Will Bitcoin reach $100,000 by December 31, 2025?
#  4        556062  MegaETH market cap (FDV) >$2B one day after la...
#  ...         ...                                                ...
#  78316    224954  Will it be possible to buy a Tesla online in t...
#  78317    628727                   Solana Up or Down on October 11?
#  78318    680295  Bitcoin Up or Down - November 14, 7:45AM-8:00A...
#  78319    692193           Bitcoin Up or Down - November 21, 5PM ET
#  78320    611773  Will the price of Solana be above $202 on Sept...
#
#                                                      slug        volume  \
#  0      will-the-price-of-bitcoin-be-between-88000-900...  8.756369e+03
#  1                              eth-updown-15m-1765258200  0.000000e+00
#  2                        solana-above-180-on-december-11  1.715047e+02
#  3      will-bitcoin-reach-100000-by-december-31-2025-...  3.008788e+06
#  4         megaeth-market-cap-fdv-2b-one-day-after-launch  2.681309e+06
#  ...                                                  ...           ...
#  78316  will-it-be-possible-to-buy-a-tesla-online-usin...  4.552531e+04
#  78317                    solana-up-or-down-on-october-11  2.996874e+04
#  78318                          btc-updown-15m-1763124300  2.357254e+04
#  78319              bitcoin-up-or-down-november-21-5pm-et  4.654276e+04
#  78320                  sol-multistrike-4h-1758787200-202  0.000000e+00
#
#         active  token_count  trade_count             first_trade  \
#  0        True            2          279 1970-01-21 10:20:54.947
#  1        True            2         1274 1970-01-21 10:20:53.977
#  2        True            2            8 1970-01-21 10:16:20.055
#  3        True            2         6795 1970-01-21 10:02:35.475
#  4        True            2         1379 1970-01-21 10:02:48.745
#  ...       ...          ...          ...                     ...
#  78316    True            2            0                     NaT
#  78317    True            2            0                     NaT
#  78318    True            2            0                     NaT
#  78319    True            2            0                     NaT
#  78320    True            2            0                     NaT
#
#                     last_trade
#  0     1970-01-21 10:21:24.701
#  1     1970-01-21 10:20:58.955
#  2     1970-01-21 10:20:55.033
#  3     1970-01-21 10:54:05.185
#  4     1970-01-21 10:59:48.219
#  ...                       ...
#  78316                     NaT
#  78317                     NaT
#  78318                     NaT
#  78319                     NaT
#  78320                     NaT
#
#  [78321 rows x 9 columns],
#  'tokens':        market_id                                           token_id outcome
#  0         240383  5558753443310276385903244358584691872713220871...     Yes
#  1         240383  1118376155299924376894090051242519981741693943...      No
#  2         240384  1134596431640604039195047120485300193791737688...     Yes
#  3         240384  1106066093543768129661579882575455780310888056...      No
#  4         240385  5054357363141436877706809771819519998261165033...     Yes
#  ...          ...                                                ...     ...
#  156631    892920  4962249368671451077147283249506517679224122335...    Down
#  156632    892921  1169185258919887144234447961803428129074298922...      Up
#  156633    892921  8272987238426133906236355761670283100898262795...    Down
#  156634    892922  6478722064042848752717023426599995341130741672...      Up
#  156635    892922  1095736752483558063085390206754178708865155509...    Down
#
#  [156636 rows x 3 columns],
#  'trades':                                                    trade_id market_id  \
#  0         0x036e539d9361b15d9ebee9bbd1aebf42e45a1e07a9bd...    570360
#  1         0x8685bb4a3134f9f664ed7e619b8ea693352f94285b34...    570360
#  2         0xab71cfe8f3cb18e629b873b65b84ea386924891e758e...    570360
#  3         0xfe619b29a0b6aa958cbd565c18f0aedc451139aac0f9...    570360
#  4         0x953032bcaecd5bf0007c44acddb0c6c9c80f2c063a55...    570360
#  ...                                                     ...       ...
#  27013719  0x4a86d7efa03d352f6990dfb61bd87f3c31a84c9b57f1...    561985
#  27013720  0x6939770889fa51da300bbab08bf1750853103848a59d...    562004
#  27013721  0x126f0595e5e8bc7039206ffc20ced52f9db85fa5ec9c...    561973
#  27013722  0x4b070936d6916aa985ad7b1dc9d6e5899642172b4003...    561991
#  27013723  0xe816815b8bdb693d8d29876ca56366b2916b901a1af1...    561991
#
#                                                     token_id  \
#  0         2148977251641003858655674434239298204418999936...
#  1         2148977251641003858655674434239298204418999936...
#  2         2148977251641003858655674434239298204418999936...
#  3         2148977251641003858655674434239298204418999936...
#  4         2148977251641003858655674434239298204418999936...
#  ...                                                     ...
#  27013719  2652814724933719576712958625055698322914303600...
#  27013720  3337233094702386052587063075854913790217057691...
#  27013721  2782897664868246677877699907621542377776697298...
#  27013722  8409529381329385248635760260604838650759146033...
#  27013723  8409529381329385248635760260604838650759146033...
#
#                         timestamp     price        size  side  \
#  0        1970-01-21 09:52:39.845  0.977000  281.054246   BUY
#  1        1970-01-21 09:52:39.857  0.977000   28.000000   BUY
#  2        1970-01-21 09:52:39.871  0.977000  182.000000   BUY
#  3        1970-01-21 09:52:39.889  0.977081   49.000000   BUY
#  4        1970-01-21 09:52:39.925  0.978000  147.800000   BUY
#  ...                          ...       ...         ...   ...
#  27013719 1970-01-21 10:59:54.319  0.992000    5.413250   BUY
#  27013720 1970-01-21 10:59:54.319  0.990000   23.151500   BUY
#  27013721 1970-01-21 10:59:54.319  0.961000   25.005179   BUY
#  27013722 1970-01-21 10:59:54.319  0.995000   25.005000   BUY
#  27013723 1970-01-21 10:59:54.317  0.994000   27.470000  SELL
#
#                                         maker_address  \
#  0         0x27d76669db4321111b08fcc7e1a5bf622b98693c
#  1         0x33dcee9b336230ed7460c98bec8ff3115296a539
#  2         0x87370aa54b8f70fa1c9637f367aadd3156782bff
#  3         0xa3ad70cf48a2f2b44163e798223c01a2c2536866
#  4         0x4ee06f42e20ee128db78d42252176bf3a9ce7cce
#  ...                                              ...
#  27013719
#  27013720
#  27013721
#  27013722
#  27013723
#
#                                         taker_address
#  0         0xc5d563a36ae78145c45a50134d48a1215220f80a
#  1         0xc5d563a36ae78145c45a50134d48a1215220f80a
#  2         0xc5d563a36ae78145c45a50134d48a1215220f80a
#  3         0xc5d563a36ae78145c45a50134d48a1215220f80a
#  4         0xc5d563a36ae78145c45a50134d48a1215220f80a
#  ...                                              ...
#  27013719
#  27013720
#  27013721
#  27013722
#  27013723
#
#  [27013724 rows x 9 columns],
#  'event_stats':                                               event_slug  market_count  \
#  0        will-binancecom-become-insolvent-by-feb-28-2023             1
#  1                               gme-market-cap-on-may-17             7
#  2                                  republican-vp-nominee            25
#  3      will-kevin-mccarthy-resign-from-the-house-by-n...             1
#  4              safe-market-cap-fdv-one-week-after-launch             6
#  ...                                                  ...           ...
#  44028                           eth-updown-4h-1765429200             1
#  44029                           sol-updown-4h-1765429200             1
#  44030                          btc-updown-15m-1765431000             1
#  44031                          eth-updown-15m-1765431000             1
#  44032  what-will-the-price-of-this-layer1-crypto-be-o...             8
#
#         total_volume  first_market_start     last_market_end
#  0            269.41 2023-01-24 21:09:31 2023-02-28 00:00:00
#  1         112281.62 2024-05-13 17:51:35 2024-05-17 12:00:00
#  2       92565642.16 2024-01-18 19:14:19 2024-09-08 12:00:00
#  3           6410.89 2023-11-12 19:11:54 2023-11-30 00:00:00
#  4         116716.82 2024-03-26 17:01:59 2024-12-31 12:00:00
#  ...             ...                 ...                 ...
#  44028          0.00 2025-12-10 05:01:33 2025-12-11 09:00:00
#  44029          0.00 2025-12-10 05:01:33 2025-12-11 09:00:00
#  44030        267.31 2025-12-10 05:32:19 2025-12-11 05:45:00
#  44031          0.00 2025-12-10 05:32:21 2025-12-11 05:45:00
#  44032      27826.46 2022-01-11 19:18:09 2022-03-01 00:00:00
#
#  [44033 rows x 5 columns]}

# %%
btc_df
# Out:
# shape: (6_221, 32)
# ┌────────────┬───────────┬───────────┬────────────┬───┬────────────┬────────┬──────────┬───────────┐
# │ time       ┆ AdrActCnt ┆ AdrBalCnt ┆ AssetCompl ┆ … ┆ SplyExpFut ┆ TxCnt  ┆ TxTfrCnt ┆ volume_re │
# │ ---        ┆ ---       ┆ ---       ┆ etionTime  ┆   ┆ 10yr       ┆ ---    ┆ ---      ┆ ported_sp │
# │ datetime[μ ┆ i64       ┆ i64       ┆ ---        ┆   ┆ ---        ┆ i64    ┆ i64      ┆ ot_usd_1d │
# │ s]         ┆           ┆           ┆ i64        ┆   ┆ f64        ┆        ┆          ┆ ---       │
# │            ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪════════════╪═══╪════════════╪════════╪══════════╪═══════════╡
# │ 2009-01-03 ┆ 0         ┆ 0         ┆ 1614334883 ┆ … ┆ null       ┆ 0      ┆ 0        ┆ null      │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2009-01-04 ┆ 0         ┆ 0         ┆ 1614334883 ┆ … ┆ null       ┆ 0      ┆ 0        ┆ null      │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2009-01-05 ┆ 0         ┆ 0         ┆ 1614334883 ┆ … ┆ null       ┆ 0      ┆ 0        ┆ null      │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2009-01-06 ┆ 0         ┆ 0         ┆ 1614334884 ┆ … ┆ null       ┆ 0      ┆ 0        ┆ null      │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2009-01-07 ┆ 0         ┆ 0         ┆ 1614334885 ┆ … ┆ null       ┆ 0      ┆ 0        ┆ null      │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ …          ┆ …         ┆ …         ┆ …          ┆ … ┆ …          ┆ …      ┆ …        ┆ …         │
# │ 2026-01-10 ┆ 608784    ┆ 55908713  ┆ 1768101454 ┆ … ┆ 2.0826e7   ┆ 492984 ┆ 1049925  ┆ 2.9985e9  │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2026-01-11 ┆ 536405    ┆ 55924280  ┆ 1768186822 ┆ … ┆ 2.0826e7   ┆ 289219 ┆ 572262   ┆ 4.3998e9  │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2026-01-12 ┆ 638422    ┆ 55917951  ┆ 1768275291 ┆ … ┆ 2.0826e7   ┆ 405384 ┆ 845895   ┆ 1.3448e10 │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2026-01-13 ┆ 701272    ┆ 55891967  ┆ 1768359739 ┆ … ┆ 2.0826e7   ┆ 340763 ┆ 731900   ┆ 1.8053e10 │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# │ 2026-01-14 ┆ null      ┆ null      ┆ null       ┆ … ┆ null       ┆ null   ┆ null     ┆ null      │
# │ 00:00:00   ┆           ┆           ┆            ┆   ┆            ┆        ┆          ┆           │
# └────────────┴───────────┴───────────┴────────────┴───┴────────────┴────────┴──────────┴───────────┘

# %%
category = poly_data['markets'].groupby('category')
print(category.groups.keys())
category.size()
# Out:
# dict_keys(['', 'Business', 'Coronavirus', 'Coronavirus-', 'Crypto', 'Global Politics', 'Politics', 'Pop-Culture ', 'Tech', 'US-current-affairs', 'Ukraine & Russia'])
# category
#                       77516
# Business                113
# Coronavirus               3
# Coronavirus-              1
# Crypto                  340
# Global Politics          56
# Politics                  1
# Pop-Culture               4
# Tech                      2
# US-current-affairs      265
# Ukraine & Russia         20
# dtype: int64

# %%
# 1. Define your keyword map
keyword_map = {
    'Crypto': 'bitcoin|eth|solana|crypto|token|airdrop',
    'Politics': 'trump|biden|harris|election|senate|republican|democrat',
    'Ukraine & Russia': 'ukraine|russia|putin|zelensky|kremlin',
    'Pop-Culture': 'oscars|grammy|taylor swift|box office|celebrity',
    'Tech': 'ai|openai|gpt|google|nvidia|meta|apple',
    'Global Politics': 'israel|gaza|iran|china|taiwan|uk|london'
}

# 2. Filter for only the rows where category is blank
blank_mask = (poly_data['markets']['category'] == '') | (poly_data['markets']['category'].isna())

# 3. Loop through the map and update blank categories based on question text
for cat, keywords in keyword_map.items():
    # Only update if the row is currently blank AND the question contains a keyword
    match_mask = blank_mask & poly_data['markets']['question'].str.contains(keywords, case=False, na=False)
    poly_data['markets'].loc[match_mask, 'category'] = cat

# 4. See how many are left blank now
print(poly_data['markets']['category'].value_counts())
# Out:
# category
# Crypto                57852
# Politics              10909
#                        7421
# Tech                    766
# Global Politics         694
# Ukraine & Russia        293
# US-current-affairs      265
# Business                113
# Pop-Culture               4
# Coronavirus               3
# Coronavirus-              1
# Name: count, dtype: int64

# %%
poly_data['markets'][poly_data['markets']['category']=='Crypto']
# Out:
#       market_id                                           question  \
# 3        243183       Will $ETH be above $3,000 on April 20, 2022?
# 9        243993  Will Bitcoin or Ethereum perform better in May...
# 11       244943          Will $UST be above $0.10 on May 23, 2022?
# 12       245033               Will $ETH be above $2,000 on May 27?
# 16       246494           Will Solana ($SOL) hit $35 or $50 first?
# ...         ...                                                ...
# 78309    242594  Will Unslashed Insurance payout for an Anchor ...
# 78311    242601      Will $ETH be above $3,400 on April 8th, 2022?
# 78313    242604  Will the price of Polygon (MATIC) be above $1....
# 78314    242618  Will the Ronin Network hacker return 90% or mo...
# 78316    242646  Will the total value locked (TVL) in DeFi be $...
#
#                                                     slug  \
# 3                will-eth-be-above-3000-on-april-20-2022
# 9      will-bitcoin-or-ethereum-perform-better-in-may...
# 11                will-ust-be-above-0pt10-on-may-23-2022
# 12                      will-eth-be-above-2000-on-may-27
# 16                    will-solana-sol-hit-35-or-50-first
# ...                                                  ...
# 78309  will-unslashed-insurance-payout-for-an-anchor-...
# 78311           will-eth-be-above-3400-on-april-8th-2022
# 78313  will-the-price-of-polygon-matic-be-above-1pt75...
# 78314  will-the-ronin-network-hacker-return-90-or-mor...
# 78316  will-the-total-value-locked-in-defi-be-85-bill...
#
#                                               event_slug category     volume  \
# 3                will-eth-be-above-3000-on-april-20-2022   Crypto  974114.26
# 9                            btc-vs-eth-performance-2022   Crypto    4941.31
# 11                will-ust-be-above-0pt10-on-may-23-2022   Crypto   13367.39
# 12                      will-eth-be-above-2000-on-may-27   Crypto  801754.44
# 16                    will-solana-sol-hit-35-or-50-first   Crypto    3060.73
# ...                                                  ...      ...        ...
# 78309  will-unslashed-insurance-payout-for-an-anchor-...   Crypto   18001.70
# 78311           will-eth-be-above-3400-on-april-8th-2022   Crypto  559956.52
# 78313  will-the-price-of-polygon-matic-be-above-1pt75...   Crypto    5405.99
# 78314  will-the-ronin-network-hacker-return-90-or-mor...   Crypto    7445.53
# 78316  will-the-total-value-locked-in-defi-be-85-bill...   Crypto    4456.20
#
#        active  closed          created_at   end_date
# 3        True    True 2022-04-12 16:51:10 2022-04-20
# 9        True    True 2022-05-01 15:39:16 2022-06-01
# 11       True    True 2022-05-17 19:31:14 2022-05-23
# 12       True    True 2022-05-19 15:55:11 2022-05-27
# 16       True    True 2022-06-06 20:12:06 2023-01-01
# ...       ...     ...                 ...        ...
# 78309    True    True 2022-03-28 21:42:48 2022-06-30
# 78311    True    True 2022-03-29 12:15:12 2022-04-08
# 78313    True    True 2022-03-29 12:39:05 2022-04-08
# 78314    True    True 2022-03-29 22:48:53 2022-04-14
# 78316    True    True 2022-03-30 22:51:47 2022-04-17
#
# [57852 rows x 10 columns]
