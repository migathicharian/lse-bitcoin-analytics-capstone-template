# %% [markdown]
# ## ETH Signal

# %%
import os
os.getcwd()
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/")

# %%
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/ETH bearish related")
# %run "backtest_template_eth.py"
# Out:
# 2026-04-14 18:23:46 INFO     Starting Bitcoin DCA Strategy Analysis
# 2026-04-14 18:23:46 INFO     Loading CoinMetrics BTC data from local file: data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-14 18:23:46 WARNING  Missing BTC-USD prices for 1 dates from 2025-04-07 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-14 18:23:46 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-14 18:23:46 INFO     Precomputing features...
# 2026-04-14 18:23:46 INFO     Running SPD backtest for 'Dynamic DCA'...
# 2026-04-14 18:23:46 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 18:23:47 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 18:23:47 INFO     Aggregated Metrics for Dynamic DCA:
# 2026-04-14 18:23:47 INFO       SPD: min=899.17, max=949.89, mean=918.46, median=916.83
# 2026-04-14 18:23:47 INFO       Percentile: min=25.93%, max=51.75%, mean=35.30%, median=34.67%
# ...

# %%
# %run "dynamic_strength_tuning_eth_bearish.py"
# Out:
# 2026-04-14 18:24:56 INFO     Loading CoinMetrics BTC data from local file: data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-14 18:24:56 WARNING  Missing BTC-USD prices for 1 dates from 2025-04-07 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-14 18:24:56 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-14 18:24:56 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 18:24:56 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 18:24:56 INFO     Aggregated Metrics for strength=-3.0:
# 2026-04-14 18:24:56 INFO       SPD: min=900.92, max=956.24, mean=922.01, median=921.27
# 2026-04-14 18:24:56 INFO       Percentile: min=26.11%, max=52.82%, mean=36.33%, median=36.05%
# 2026-04-14 18:24:56 INFO       Exp-decay avg SPD percentile: 38.25%
# 2026-04-14 18:24:56 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# Loading BTC data...
# ...
