# %% [markdown]
# ## ETH Signal

# %%
import os
os.getcwd()
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/")

# %%
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/ETH bullish related")
# %run "backtest_template_eth.py"
# Out:
# 2026-04-14 15:48:04 INFO     Starting Bitcoin DCA Strategy Analysis
# 2026-04-14 15:48:04 INFO     Loading CoinMetrics BTC data from local file: data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-14 15:48:04 WARNING  Missing BTC-USD prices for 1 dates from 2025-04-07 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-14 15:48:04 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-14 15:48:04 INFO     Precomputing features...
# 2026-04-14 15:48:04 INFO     Running SPD backtest for 'Dynamic DCA'...
# 2026-04-14 15:48:04 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 15:48:04 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 15:48:04 INFO     Aggregated Metrics for Dynamic DCA:
# 2026-04-14 15:48:04 INFO       SPD: min=899.09, max=949.81, mean=918.29, median=916.51
# 2026-04-14 15:48:04 INFO       Percentile: min=25.92%, max=51.69%, mean=35.25%, median=34.59%
# ...

# %%
# %run "dynamic_strength_tuning_eth_bullish.py"
# Out:
# 2026-04-14 15:48:12 INFO     Loading CoinMetrics BTC data from local file: data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-14 15:48:12 WARNING  Missing BTC-USD prices for 1 dates from 2025-04-07 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-14 15:48:12 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-14 15:48:12 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 15:48:12 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 15:48:12 INFO     Aggregated Metrics for strength=-3.0:
# 2026-04-14 15:48:12 INFO       SPD: min=899.33, max=950.89, mean=918.84, median=917.08
# 2026-04-14 15:48:12 INFO       Percentile: min=25.90%, max=51.88%, mean=35.40%, median=34.73%
# 2026-04-14 15:48:12 INFO       Exp-decay avg SPD percentile: 37.30%
# 2026-04-14 15:48:12 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# Loading BTC data...
# ...
