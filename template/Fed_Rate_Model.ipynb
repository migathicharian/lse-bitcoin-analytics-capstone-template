# %% [markdown]
# ## Fed Rate Signal

# %%
import os
os.getcwd()
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/")

# %%
# %run eda/eda_starter_template.py
# Out:
# [Memory] Initial memory usage: 252.95 MB
#
# Loading Bitcoin data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv...
# [Memory] Before loading Bitcoin data: 252.95 MB
# [Memory] After loading Bitcoin data: 272.70 MB (Δ 19.75 MB)
# Successfully loaded 6221 rows.
# Loading Polymarket data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket...
# [Memory] Before loading Polymarket data: 272.73 MB
# [Memory] After loading Polymarket data: 272.73 MB (Δ 0.00 MB)
# [Memory] Before analyzing Bitcoin metrics: 272.73 MB
#
# --- Bitcoin Data Summary ---
# shape: (9, 4)
# ┌────────────┬───────────────┬───────────────┬───────────┐
# │ statistic  ┆ PriceUSD      ┆ CapMrktCurUSD ┆ HashRate  │
# │ ---        ┆ ---           ┆ ---           ┆ ---       │
# │ str        ┆ f64           ┆ f64           ┆ f64       │
# ╞════════════╪═══════════════╪═══════════════╪═══════════╡
# ...

# %%
btc_df = load_bitcoin_data(COINMETRICS_PATH)
# Out:
# Loading Bitcoin data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv...
# [Memory] Before loading Bitcoin data: 288.86 MB
# [Memory] After loading Bitcoin data: 290.84 MB (Δ 1.98 MB)
# Successfully loaded 6221 rows.

# %%
btc_df = btc_df.to_pandas

# %%
btc_df = btc_df()

# %%
import pandas as pd
btc_df = btc_df.set_index("time")

# %%
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/")
fed_signal = pd.read_csv("fed_signal.csv", header = 0)

# %%
fed_signal.name = 'fed_signal'

# %%
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/")
# %run "model_development_template_fed_rate.py"

# %%
fed_signal
# Out:
#            date  fed_signal
# 0    2025-04-07         NaN
# 1    2025-04-08    0.078253
# 2    2025-04-09    0.005726
# 3    2025-04-10   -0.003861
# 4    2025-04-11    0.000973
# ..          ...         ...
# 225  2025-12-31    0.107941
# 226  2026-01-01   -0.186852
# 227  2026-01-02   -0.090837
# 228  2026-01-03    0.288731
# 229  2026-01-05   -0.186542
#
# [230 rows x 2 columns]

# %%
_FEATURES_DF = precompute_features(btc_df, fed_signal['fed_signal'])

# %%
# %run "backtest_template_fed_rate.py"
# Out:
# 2026-04-13 12:31:23 INFO     Starting Bitcoin DCA Strategy Analysis
# 2026-04-13 12:31:23 INFO     Loading CoinMetrics BTC data from local file: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-13 12:31:23 WARNING  Missing BTC-USD prices for 1 dates from 2025-01-01 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-13 12:31:23 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-13 12:31:23 INFO     Precomputing features...
# 2026-04-13 12:31:23 INFO     Running SPD backtest for 'Dynamic DCA'...
# 2026-04-13 12:31:23 INFO     Backtesting date range: 2025-01-01 to 2026-01-31 (31 total windows)
# 2026-04-13 12:31:23 INFO     ✓ Validated weight sums for 31 windows (all sum to 1.0)
# 2026-04-13 12:31:23 INFO     Aggregated Metrics for Dynamic DCA:
# 2026-04-13 12:31:23 INFO       SPD: min=996.64, max=999.68, mean=997.91, median=997.66
# ...
