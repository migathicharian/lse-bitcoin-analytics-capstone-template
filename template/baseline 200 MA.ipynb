# %%
import os
os.getcwd()
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/")

# %%
# %run "backtest_template.py"
# Out:
# 2026-04-13 12:01:11 INFO     Starting Bitcoin DCA Strategy Analysis
# 2026-04-13 12:01:11 INFO     Loading CoinMetrics BTC data from local file: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-13 12:01:11 WARNING  Missing BTC-USD prices for 1 dates from 2018-01-01 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-13 12:01:11 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-13 12:01:11 INFO     Precomputing features...
# 2026-04-13 12:01:11 INFO     Running SPD backtest for 'Dynamic DCA'...
# 2026-04-13 12:01:11 INFO     Backtesting date range: 2018-01-01 to 2025-12-31 (2557 total windows)
# 2026-04-13 12:01:16 INFO     ✓ Validated weight sums for 2557 windows (all sum to 1.0)
# 2026-04-13 12:01:16 INFO     Aggregated Metrics for Dynamic DCA:
# 2026-04-13 12:01:16 INFO       SPD: min=1004.32, max=20313.77, mean=6673.19, median=3939.56
# 2026-04-13 12:01:16 INFO       Percentile: min=17.63%, max=73.04%, mean=39.74%, median=39.45%
# 2026-04-13 12:01:16 INFO       Exp-decay avg SPD percentile: 42.43%
# 2026-04-13 12:01:16 INFO     Running strategy validation...
# Validating strategy submission readiness...
# 2026-04-13 12:01:24 INFO     Backtesting date range: 2018-01-01 to 2025-12-31 (2557 total windows)
# 2026-04-13 12:01:29 INFO     ✓ Validated weight sums for 2557 windows (all sum to 1.0)
# ⚠️ Windows where strategy underperformed Uniform DCA:
#                          dynamic_percentile  uniform_percentile     Delta
# window
# 2018-10-27 → 2019-10-27           41.979515           42.184367 -0.204851
# 2018-10-29 → 2019-10-29           41.805001           42.070124 -0.265122
# 2018-10-30 → 2019-10-30           42.007191           42.011404 -0.004213
# 2018-10-31 → 2019-10-31           41.881028           41.953332 -0.072304
# 2018-11-01 → 2019-11-01           41.548311           41.894946 -0.346635
# ...                                     ...                 ...       ...
# 2024-09-08 → 2025-09-08           28.345757           28.747581 -0.401824
# 2024-09-09 → 2025-09-09           30.451677           30.699404 -0.247726
# 2024-09-10 → 2025-09-10           30.543384           30.718194 -0.174810
# 2024-09-11 → 2025-09-11           30.354380           30.463686 -0.109306
# 2024-09-12 → 2025-09-12           30.896661           30.916775 -0.020114
#
# [996 rows x 3 columns]
# 2026-04-13 12:01:29 INFO     Final Model Score: 51.74%
# 2026-04-13 12:01:29 INFO       Excess percentile: mean=1.04%, median=1.23%
# 2026-04-13 12:01:29 INFO       Relative improvement: mean=2.61%, median=3.37%
# 2026-04-13 12:01:29 INFO       Ratio (dynamic/uniform): mean=1.03, median=1.03
# 2026-04-13 12:01:29 INFO     Generating visualizations...
# Summary: 996/2557 underperformed (61.05% win rate)
# ✅ Strategy meets performance requirement (≥ 50% win rate vs. uniform DCA).
#
# ✅ Strategy is ready for submission.
# 2026-04-13 12:01:29 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/performance_comparison.svg
# 2026-04-13 12:01:29 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/excess_percentile_distribution.svg
# 2026-04-13 12:01:29 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/win_loss_comparison.svg
# 2026-04-13 12:01:30 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/cumulative_performance.svg
# 2026-04-13 12:01:30 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/metrics_summary.svg
# 2026-04-13 12:01:30 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/metrics.json
# 2026-04-13 12:01:30 INFO     All outputs saved to '/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/output/' directory
