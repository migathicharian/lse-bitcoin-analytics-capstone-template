# %% [markdown]
# ## Fed Rate Signal

# %%
import os
os.getcwd()
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/")

# %%
# %run eda/eda_starter_template.py
# Out:
# [Memory] Initial memory usage: 253.61 MB
#
# Loading Bitcoin data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv...
# [Memory] Before loading Bitcoin data: 253.61 MB
# [Memory] After loading Bitcoin data: 273.38 MB (Δ 19.77 MB)
# Successfully loaded 6221 rows.
# Loading Polymarket data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Polymarket...
# [Memory] Before loading Polymarket data: 273.39 MB
# [Memory] After loading Polymarket data: 273.39 MB (Δ 0.00 MB)
# [Memory] Before analyzing Bitcoin metrics: 273.39 MB
#
# --- Bitcoin Data Summary ---
# shape: (9, 4)
# ┌────────────┬───────────────┬───────────────┬───────────┐
# │ statistic  ┆ PriceUSD      ┆ CapMrktCurUSD ┆ HashRate  │
# │ ---        ┆ ---           ┆ ---           ┆ ---       │
# │ str        ┆ f64           ┆ f64           ┆ f64       │
# ╞════════════╪═══════════════╪═══════════════╪═══════════╡
# │ count      ┆ 5659.0        ┆ 5659.0        ┆ 6214.0    │
# │ null_count ┆ 562.0         ┆ 562.0         ┆ 7.0       │
# │ mean       ┆ 19809.987841  ┆ 3.8264e11     ┆ 1.5146e8  │
# │ std        ┆ 29699.078673  ┆ 5.8737e11     ┆ 2.6345e8  │
# │ min        ┆ 0.050541      ┆ 177670.489754 ┆ 1.9884e-7 │
# │ 25%        ┆ 260.651331    ┆ 3.6730e9      ┆ 62.554011 │
# │ 50%        ┆ 5728.351702   ┆ 9.7931e10     ┆ 5.5673e6  │
# │ 75%        ┆ 28844.613678  ┆ 5.5492e11     ┆ 1.6529e8  │
# │ max        ┆ 124824.453667 ┆ 2.4879e12     ┆ 1.3055e9  │
# └────────────┴───────────────┴───────────────┴───────────┘
# Saved btc_correlation_matrix.png
# [Memory] After analyzing Bitcoin metrics: 285.86 MB (Δ 12.47 MB)
# [Memory] Before plotting Bitcoin price: 285.86 MB
# Saved btc_price_history.png
# [Memory] After plotting Bitcoin price: 293.16 MB (Δ 7.30 MB)
#
# [Memory] Final memory usage: 293.16 MB (Total Δ: 39.55 MB)
#
# EDA Layout Complete. Check the 'plots' directory for visualizations.

# %%
btc_df = load_bitcoin_data(COINMETRICS_PATH)
# Out:
# Loading Bitcoin data from /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/data/Coin Metrics/coinmetrics_btc.csv...
# [Memory] Before loading Bitcoin data: 293.16 MB
# [Memory] After loading Bitcoin data: 294.84 MB (Δ 1.69 MB)
# Successfully loaded 6221 rows.

# %%
btc_df = btc_df.to_pandas

# %%
btc_df = btc_df()

# %%
import pandas as pd
btc_df = btc_df.set_index("time")

# %%
os.chdir("/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/fed rate")
# %run "model_development_template_fed_rate.py"

# %%
# %run "backtest_template_fed_rate.py"
# Out:
# 2026-04-14 00:52:33 INFO     Starting Bitcoin DCA Strategy Analysis
# 2026-04-14 00:52:33 INFO     Loading CoinMetrics BTC data from local file: data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-14 00:52:33 WARNING  Missing BTC-USD prices for 1 dates from 2025-04-07 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-14 00:52:33 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-14 00:52:33 INFO     Precomputing features...
# 2026-04-14 00:52:33 INFO     Running SPD backtest for 'Dynamic DCA'...
# 2026-04-14 00:52:33 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:52:33 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:52:33 INFO     Aggregated Metrics for Dynamic DCA:
# 2026-04-14 00:52:33 INFO       SPD: min=899.10, max=949.99, mean=918.34, median=916.58
# 2026-04-14 00:52:33 INFO       Percentile: min=25.95%, max=51.71%, mean=35.26%, median=34.60%
# 2026-04-14 00:52:33 INFO       Exp-decay avg SPD percentile: 36.90%
# 2026-04-14 00:52:33 INFO     Running strategy validation...
#                          min_sats_per_dollar  max_sats_per_dollar  \
# window
# 2025-04-07 → 2025-10-07           801.125077          1309.733172
# 2025-04-08 → 2025-10-08           801.125077          1309.733172
# 2025-04-09 → 2025-10-09           801.125077          1256.929518
# 2025-04-10 → 2025-10-10           801.125077          1256.929518
# 2025-04-11 → 2025-10-11           801.125077          1199.617569
#
#                          uniform_sats_per_dollar  dynamic_sats_per_dollar  \
# window
# 2025-04-07 → 2025-10-07               935.427952               935.514384
# 2025-04-08 → 2025-10-08               932.989561               933.103082
# 2025-04-09 → 2025-10-09               930.340717               930.489275
# 2025-04-10 → 2025-10-10               928.548297               928.608342
# 2025-04-11 → 2025-10-11               926.616001               926.682845
#
#                          uniform_percentile  dynamic_percentile  \
# window
# 2025-04-07 → 2025-10-07           26.405965           26.422959
# 2025-04-08 → 2025-10-08           25.926541           25.948861
# 2025-04-09 → 2025-10-09           28.348921           28.381513
# 2025-04-10 → 2025-10-10           27.955678           27.968851
# 2025-04-11 → 2025-10-11           31.491415           31.508189
#
#                          excess_percentile
# window
# 2025-04-07 → 2025-10-07           0.016994
# 2025-04-08 → 2025-10-08           0.022320
# 2025-04-09 → 2025-10-09           0.032593
# 2025-04-10 → 2025-10-10           0.013174
# 2025-04-11 → 2025-10-11           0.016774
# ['min_sats_per_dollar', 'max_sats_per_dollar', 'uniform_sats_per_dollar', 'dynamic_sats_per_dollar', 'uniform_percentile', 'dynamic_percentile', 'excess_percentile']
# Validating strategy submission readiness...
# 2026-04-14 00:52:37 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:52:37 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# ⚠️ Windows where strategy underperformed Uniform DCA:
#                          dynamic_percentile  uniform_percentile     Delta
# window
# 2025-04-16 → 2025-10-16           30.294901           30.301507 -0.006605
# 2025-04-26 → 2025-10-26           39.813611           39.830114 -0.016502
# 2025-04-27 → 2025-10-27           39.451462           39.461724 -0.010262
# 2025-06-24 → 2025-12-24           35.970041           35.972407 -0.002366
# 2025-06-25 → 2025-12-25           36.261396           36.263428 -0.002032
# 2025-06-26 → 2025-12-26           36.568330           36.569433 -0.001103
# 2025-06-28 → 2025-12-28           37.156260           37.160617 -0.004357
# 2025-06-29 → 2025-12-29           37.469988           37.471076 -0.001088
# 2026-04-14 00:52:37 INFO     Final Model Score: 64.00%
# 2026-04-14 00:52:37 INFO       Excess percentile: mean=0.02%, median=0.02%
# 2026-04-14 00:52:37 INFO       Relative improvement: mean=0.06%, median=0.06%
# 2026-04-14 00:52:37 INFO       Ratio (dynamic/uniform): mean=1.00, median=1.00
# 2026-04-14 00:52:37 INFO     Generating visualizations...
# 2026-04-14 00:52:37 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/performance_comparison.svg
# Summary: 8/90 underperformed (91.11% win rate)
# ✅ Strategy meets performance requirement (≥ 50% win rate vs. uniform DCA).
#
# ✅ Strategy is ready for submission.
# 2026-04-14 00:52:37 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/excess_percentile_distribution.svg
# 2026-04-14 00:52:37 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/win_loss_comparison.svg
# 2026-04-14 00:52:37 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/cumulative_performance.svg
# 2026-04-14 00:52:37 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/metrics_summary.svg
# 2026-04-14 00:52:37 INFO     ✓ Saved: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/metrics.json
# 2026-04-14 00:52:37 INFO     All outputs saved to '/Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/output fed rate/' directory

# %%
# %run "dynamic strength tuning.py"
# Out:
# 2026-04-14 00:50:34 INFO     Loading CoinMetrics BTC data from local file: data/Coin Metrics/coinmetrics_btc.csv
# 2026-04-14 00:50:34 WARNING  Missing BTC-USD prices for 1 dates from 2025-04-07 to 2026-01-14. First missing date: 2026-01-14
# 2026-04-14 00:50:34 INFO     Loaded CoinMetrics data: 6221 rows, 2009-01-03 to 2026-01-14
# 2026-04-14 00:50:34 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:50:34 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:34 INFO     Aggregated Metrics for strength=-3.0:
# 2026-04-14 00:50:34 INFO       SPD: min=899.37, max=951.71, mean=918.92, median=917.56
# 2026-04-14 00:50:34 INFO       Percentile: min=26.21%, max=52.03%, mean=35.43%, median=34.66%
# 2026-04-14 00:50:34 INFO       Exp-decay avg SPD percentile: 37.03%
# 2026-04-14 00:50:34 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# Loading BTC data...
# Sweeping 12 values of DYNAMIC_STRENGTH...
#
#   strength=-3.00 | score=62.40% | win_rate=87.8% | mean_excess=+0.187%
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=-2.0:
# 2026-04-14 00:50:35 INFO       SPD: min=899.29, max=951.09, mean=918.73, median=917.24
# 2026-04-14 00:50:35 INFO       Percentile: min=26.11%, max=51.92%, mean=35.37%, median=34.65%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.99%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=-1.5:
# 2026-04-14 00:50:35 INFO       SPD: min=899.24, max=950.78, mean=918.63, median=917.09
# 2026-04-14 00:50:35 INFO       Percentile: min=26.06%, max=51.87%, mean=35.34%, median=34.64%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.97%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
#   strength=-2.00 | score=62.94% | win_rate=88.9% | mean_excess=+0.133%
#   strength=-1.50 | score=63.48% | win_rate=90.0% | mean_excess=+0.103%
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=-1.0:
# 2026-04-14 00:50:35 INFO       SPD: min=899.19, max=950.47, mean=918.52, median=916.90
# 2026-04-14 00:50:35 INFO       Percentile: min=26.02%, max=51.81%, mean=35.31%, median=34.63%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.94%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=-0.5:
# 2026-04-14 00:50:35 INFO       SPD: min=899.13, max=950.15, mean=918.40, median=916.69
# 2026-04-14 00:50:35 INFO       Percentile: min=25.97%, max=51.75%, mean=35.28%, median=34.61%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.91%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
#   strength=-1.00 | score=63.47% | win_rate=90.0% | mean_excess=+0.071%
#   strength=-0.50 | score=63.46% | win_rate=90.0% | mean_excess=+0.037%
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=-0.25:
# 2026-04-14 00:50:35 INFO       SPD: min=899.10, max=949.99, mean=918.34, median=916.58
# 2026-04-14 00:50:35 INFO       Percentile: min=25.95%, max=51.71%, mean=35.26%, median=34.60%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.90%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=0.25:
# 2026-04-14 00:50:35 INFO       SPD: min=899.03, max=949.75, mean=918.24, median=916.44
# 2026-04-14 00:50:35 INFO       Percentile: min=25.90%, max=51.68%, mean=35.23%, median=34.59%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.87%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
#   strength=-0.25 | score=64.00% | win_rate=91.1% | mean_excess=+0.019%
#   strength=+0.25 | score=31.21% | win_rate=25.6% | mean_excess=-0.009%
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=0.5:
# 2026-04-14 00:50:35 INFO       SPD: min=898.99, max=949.68, mean=918.21, median=916.41
# 2026-04-14 00:50:35 INFO       Percentile: min=25.88%, max=51.68%, mean=35.22%, median=34.58%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.86%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=1.0:
# 2026-04-14 00:50:35 INFO       SPD: min=898.91, max=949.54, mean=918.13, median=916.31
# 2026-04-14 00:50:35 INFO       Percentile: min=25.84%, max=51.68%, mean=35.20%, median=34.58%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.85%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
#   strength=+0.50 | score=30.10% | win_rate=23.3% | mean_excess=-0.019%
#   strength=+1.00 | score=28.42% | win_rate=20.0% | mean_excess=-0.042%
# 2026-04-14 00:50:35 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:35 INFO     Aggregated Metrics for strength=1.5:
# 2026-04-14 00:50:35 INFO       SPD: min=898.83, max=949.42, mean=918.03, median=916.17
# 2026-04-14 00:50:35 INFO       Percentile: min=25.79%, max=51.68%, mean=35.17%, median=34.57%
# 2026-04-14 00:50:35 INFO       Exp-decay avg SPD percentile: 36.82%
# 2026-04-14 00:50:35 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
# 2026-04-14 00:50:36 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:36 INFO     Aggregated Metrics for strength=2.0:
# 2026-04-14 00:50:36 INFO       SPD: min=898.73, max=949.30, mean=917.92, median=915.97
# 2026-04-14 00:50:36 INFO       Percentile: min=25.75%, max=51.67%, mean=35.14%, median=34.55%
# 2026-04-14 00:50:36 INFO       Exp-decay avg SPD percentile: 36.79%
# 2026-04-14 00:50:36 INFO     Backtesting date range: 2025-04-07 to 2026-01-05 (90 total windows)
#   strength=+1.50 | score=27.30% | win_rate=17.8% | mean_excess=-0.070%
#   strength=+2.00 | score=27.29% | win_rate=17.8% | mean_excess=-0.103%
# 2026-04-14 00:50:36 INFO     ✓ Validated weight sums for 90 windows (all sum to 1.0)
# 2026-04-14 00:50:36 INFO     Aggregated Metrics for strength=3.0:
# 2026-04-14 00:50:36 INFO       SPD: min=898.51, max=949.12, mean=917.64, median=915.42
# 2026-04-14 00:50:36 INFO       Percentile: min=25.66%, max=51.63%, mean=35.06%, median=34.50%
# 2026-04-14 00:50:36 INFO       Exp-decay avg SPD percentile: 36.73%
# 2026-04-14 00:50:36 INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-14 00:50:36 INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-14 00:50:36 INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-14 00:50:36 INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-14 00:50:36 INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-04-14 00:50:36 INFO     Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
#   strength=+3.00 | score=22.25% | win_rate=7.8% | mean_excess=-0.184%
#
# ======================================================================
# RESULTS (sorted by score, best first)
# ======================================================================
#  strength   score  win_rate  exp_decay_pct  mean_excess  median_excess  wins  losses
#     -0.25 64.0036   91.1111        36.8961       0.0189         0.0206    82       8
#     -1.50 63.4834   90.0000        36.9667       0.1032         0.1119    81       9
#     -1.00 63.4706   90.0000        36.9411       0.0714         0.0785    81       9
#     -0.50 63.4560   90.0000        36.9120       0.0371         0.0409    81       9
#     -2.00 62.9391   88.8889        36.9893       0.1329         0.1420    80      10
#     -3.00 62.4021   87.7778        37.0264       0.1870         0.2002    79      11
#      0.25 31.2139   25.5556        36.8722      -0.0090        -0.0107    23      67
#      0.50 30.0988   23.3333        36.8642      -0.0190        -0.0226    21      69
#      1.00 28.4226   20.0000        36.8452      -0.0423        -0.0495    18      72
#      1.50 27.2999   17.7778        36.8221      -0.0703        -0.0802    16      74
#      2.00 27.2863   17.7778        36.7948      -0.1033        -0.1145    16      74
#      3.00 22.2526    7.7778        36.7274      -0.1845        -0.1898     7      83
#
# ✅ Best DYNAMIC_STRENGTH = -0.25 (score=64.00%, win_rate=91.1%)
# Plot saved to: /Users/mig/Documents/LSE/Capstone Project/lse-bitcoin-analytics-capstone-template/template/fed rate/dynamic_strength_sweep.png
